# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_csv('E:/HDD Documents/HDD Documents/School/WGU/d208_predictive_modeling/medical/medical_clean.csv')

# %%
df.rename(columns = {'Item1':'TimelyA', 'Item2':'TimelyT', 'Item3':'TimelyV', 'Item4':'Reliability', 'Item5': 'Options', 'Item6':'HoT', 'Item7':'Courteous','Item8':'ActiveLis'}, inplace = True)

# %%
df.head()
# Out:
#    CaseOrder Customer_id                           Interaction  \
# 0          1     C412403  8cd49b13-f45a-4b47-a2bd-173ffa932c2f
# 1          2     Z919181  d2450b70-0337-4406-bdbb-bc1037f1734c
# 2          3     F995323  a2057123-abf5-4a2c-abad-8ffe33512562
# 3          4     A879973  1dec528d-eb34-4079-adce-0d7a40e82205
# 4          5     C544523  5885f56b-d6da-43a3-8760-83583af94266
#
#                                 UID          City State        County    Zip  \
# 0  3a83ddb66e2ae73798bdf1d705dc0932           Eva    AL        Morgan  35621
# 1  176354c5eef714957d486009feabf195      Marianna    FL       Jackson  32446
# 2  e19a0fa00aeda885b8a436757e889bc9   Sioux Falls    SD     Minnehaha  57110
# 3  cd17d7b6d152cb6f23957346d11c3f07  New Richland    MN        Waseca  56072
# 4  d2f0425877b10ed6bb381f3e2579424a    West Point    VA  King William  23181
#
#         Lat       Lng  ...  TotalCharge Additional_charges TimelyA TimelyT  \
# 0  34.34960 -86.72508  ...  3726.702860       17939.403420       3       3
# 1  30.84513 -85.22907  ...  4193.190458       17612.998120       3       4
# 2  43.54321 -96.63772  ...  2434.234222       17505.192460       2       4
# 3  43.89744 -93.51479  ...  2127.830423       12993.437350       3       5
# 4  37.59894 -76.88958  ...  2113.073274        3716.525786       2       1
#
#    TimelyV  Reliability  Options HoT Courteous ActiveLis
# 0        2            2        4   3         3         4
# 1        3            4        4   4         3         3
# 2        4            4        3   4         3         3
# 3        5            3        4   5         5         5
# 4        3            3        5   3         4         3
#
# [5 rows x 50 columns]

# %%
df = df.drop(['Children', 'Income', 'Marital', 'VitD_levels', 'Full_meals_eaten', 'vitD_supp', 'Soft_drink', 'HighBlood', 'Stroke', 'Complication_risk', 'Arthritis', 'Diabetes', 'Hyperlipidemia', 'Allergic_rhinitis', 'Reflux_esophagitis', 'Services', 'TotalCharge', 'Additional_charges', 'BackPain','Anxiety', 'CaseOrder','Customer_id','Interaction','UID','City','State','County','Zip','Lat','Lng','Population','Area','TimeZone','Job'], axis = 1)

# %%
df = df[['Initial_days', 'Age', 'Gender', 'ReAdmis','Doc_visits', 'Initial_admin', 'Overweight', 'Asthma', 'TimelyA', 'TimelyT', 'TimelyV', 'Reliability', 'Options', 'HoT', 'Courteous', 'ActiveLis']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Initial_days   10000 non-null  float64
#  1   Age            10000 non-null  int64
#  2   Gender         10000 non-null  object
#  3   ReAdmis        10000 non-null  object
#  4   Doc_visits     10000 non-null  int64
#  5   Initial_admin  10000 non-null  object
#  6   Overweight     10000 non-null  object
#  7   Asthma         10000 non-null  object
#  8   TimelyA        10000 non-null  int64
#  9   TimelyT        10000 non-null  int64
#  10  TimelyV        10000 non-null  int64
#  11  Reliability    10000 non-null  int64
#  12  Options        10000 non-null  int64
#  13  HoT            10000 non-null  int64
#  14  Courteous      10000 non-null  int64
#  15  ActiveLis      10000 non-null  int64
# dtypes: float64(1), int64(10), object(5)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#        Initial_days           Age    Doc_visits       TimelyA       TimelyT  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      34.455299     53.511700      5.012200      3.518800      3.506700
# std       26.309341     20.638538      1.045734      1.031966      1.034825
# min        1.001981     18.000000      1.000000      1.000000      1.000000
# 25%        7.896215     36.000000      4.000000      3.000000      3.000000
# 50%       35.836244     53.000000      5.000000      4.000000      3.000000
# 75%       61.161020     71.000000      6.000000      4.000000      4.000000
# max       71.981490     89.000000      9.000000      8.000000      7.000000
#
#             TimelyV   Reliability       Options           HoT     Courteous  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       3.511100      3.515100      3.496900      3.522500      3.494000
# std        1.032755      1.036282      1.030192      1.032376      1.021405
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.000000      3.000000      3.000000      3.000000      3.000000
# 50%        4.000000      4.000000      3.000000      4.000000      3.000000
# 75%        4.000000      4.000000      4.000000      4.000000      4.000000
# max        8.000000      7.000000      7.000000      7.000000      7.000000
#
#           ActiveLis
# count  10000.000000
# mean       3.509700
# std        1.042312
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        7.000000

# %%
df.corr()
# Out:
# C:\Users\nsgoo\AppData\Local\Temp\ipykernel_24960\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               Initial_days       Age  Doc_visits   TimelyA   TimelyT  \
# Initial_days      1.000000  0.016264   -0.006754 -0.022258 -0.007738
# Age               0.016264  1.000000    0.006898  0.005552  0.003967
# Doc_visits       -0.006754  0.006898    1.000000  0.003680  0.006024
# TimelyA          -0.022258  0.005552    0.003680  1.000000  0.655578
# TimelyT          -0.007738  0.003967    0.006024  0.655578  1.000000
# TimelyV          -0.010817  0.004709   -0.002718  0.579585  0.521728
# Reliability      -0.011748  0.003377   -0.006538 -0.004614  0.003077
# Options           0.004132 -0.008827   -0.009434 -0.000368 -0.010018
# HoT              -0.011752 -0.002087    0.012530  0.421233  0.366075
# Courteous         0.001279  0.009423    0.008589  0.332855  0.291039
# ActiveLis        -0.008034 -0.003367    0.004571  0.278067  0.242962
#
#                TimelyV  Reliability   Options       HoT  Courteous  ActiveLis
# Initial_days -0.010817    -0.011748  0.004132 -0.011752   0.001279  -0.008034
# Age           0.004709     0.003377 -0.008827 -0.002087   0.009423  -0.003367
# Doc_visits   -0.002718    -0.006538 -0.009434  0.012530   0.008589   0.004571
# TimelyA       0.579585    -0.004614 -0.000368  0.421233   0.332855   0.278067
# TimelyT       0.521728     0.003077 -0.010018  0.366075   0.291039   0.242962
# TimelyV       1.000000    -0.006324 -0.010496  0.312874   0.252302   0.209498
# Reliability  -0.006324     1.000000 -0.447372  0.235444   0.192223   0.161528
# Options      -0.010496    -0.447372  1.000000 -0.310154  -0.268186  -0.229557
# HoT           0.312874     0.235444 -0.310154  1.000000   0.377368   0.319886
# Courteous     0.252302     0.192223 -0.268186  0.377368   1.000000   0.274499
# ActiveLis     0.209498     0.161528 -0.229557  0.319886   0.274499   1.000000

# %%
my_list = df.columns.values.tolist()
my_list
# Out:
# ['Initial_days',
#  'Age',
#  'Gender',
#  'ReAdmis',
#  'Doc_visits',
#  'Initial_admin',
#  'Overweight',
#  'Asthma',
#  'TimelyA',
#  'TimelyT',
#  'TimelyV',
#  'Reliability',
#  'Options',
#  'HoT',
#  'Courteous',
#  'ActiveLis']

# %%
df.to_csv('E:/HDD Documents/HDD Documents/School/WGU/d208_predictive_modeling/medical_cleaned208_v3.csv')

# %%
df.hist('Initial_days', bins = 50)
df.hist('TimelyA', bins = 50)
# Out:
# array([[<AxesSubplot: title={'center': 'TimelyA'}>]], dtype=object)

# %%
df.boxplot(['Initial_days'])
# Out:
# <AxesSubplot: >

# %%
tbl = pd.pivot_table(df.groupby(['ReAdmis']).size().reset_index(), values = 0, index = 'ReAdmis', columns = ['ReAdmis'], aggfunc = np.sum)
tbl.plot(kind = 'bar', stacked = 'True')
# Out:
# <AxesSubplot: xlabel='ReAdmis'>

# %%
tbl = pd.pivot_table(df.groupby(['Asthma']).size().reset_index(), values = 0, index = 'Asthma', columns = ['Asthma'], aggfunc = np.sum)
tbl.plot(kind = 'bar', stacked = 'True')
# Out:
# <AxesSubplot: xlabel='Asthma'>

# %%
sns.scatterplot(x = df['ReAdmis'],y = df['Initial_days'],color = 'blue')
plt.show()
sns.scatterplot(x = df['Initial_admin'],y = df['Initial_days'],color = 'blue')
plt.show()

# %%
sns.scatterplot(x = df['Doc_visits'],y = df['Initial_days'],color = 'red')
plt.show()
sns.scatterplot(x = df['TimelyA'],y = df['Initial_days'],color = 'red')
plt.show()
sns.scatterplot(x = df['Options'],y = df['Initial_days'],color = 'red')
plt.show()

# %%
df.to_csv('E:/HDD Documents/HDD Documents/School/WGU/d208_predictive_modeling/medical_cleaned208_v4.csv', index = False)

# %%
df = df.replace(to_replace = ['Yes','No'],value = [1,0])
df['Initial_admin'] = df['Initial_admin'].replace(['Elective Admission','Observation Admission','Emergency Admission'],[1,2,3])
df
# Out:
#       Initial_days  Age  Gender  ReAdmis  Doc_visits  Initial_admin  \
# 0        10.585770   53    Male        0           6              3
# 1        15.129562   51  Female        0           4              3
# 2         4.772177   53  Female        0           4              1
# 3         1.714879   78    Male        0           4              1
# 4         1.254807   22  Female        0           5              1
# ...            ...  ...     ...      ...         ...            ...
# 9995     51.561220   25    Male        0           4              3
# 9996     68.668240   87    Male        1           5              1
# 9997     70.154180   45  Female        1           4              1
# 9998     63.356900   43    Male        1           5              3
# 9999     70.850590   70  Female        1           5              2
#
#       Overweight  Asthma  TimelyA  TimelyT  TimelyV  Reliability  Options  \
# 0              0       1        3        3        2            2        4
# 1              1       0        3        4        3            4        4
# 2              1       0        2        4        4            4        3
# 3              0       1        3        5        5            3        4
# 4              0       0        2        1        3            3        5
# ...          ...     ...      ...      ...      ...          ...      ...
# 9995           0       0        3        2        2            3        4
# 9996           1       1        3        3        4            2        5
# 9997           1       0        3        3        3            4        4
# 9998           1       0        5        5        3            4        4
# 9999           1       0        4        3        3            2        3
#
#       HoT  Courteous  ActiveLis
# 0       3          3          4
# 1       4          3          3
# 2       4          3          3
# 3       5          5          5
# 4       3          4          3
# ...   ...        ...        ...
# 9995    3          4          2
# 9996    3          4          4
# 9997    2          3          2
# 9998    3          4          3
# 9999    6          4          3
#
# [10000 rows x 16 columns]

# %%
df['intercept'] = 1
model = sm.OLS(df['Initial_days'],df[['Asthma','TimelyA', 'TimelyT', 'TimelyV', 'Reliability', 'Options', 'HoT', 'Courteous', 'ActiveLis', 'intercept']]).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Initial_days   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.160
# Date:                Sun, 06 Nov 2022   Prob (F-statistic):              0.316
# Time:                        22:21:53   Log-Likelihood:                -46883.
# No. Observations:               10000   AIC:                         9.379e+04
# Df Residuals:                    9990   BIC:                         9.386e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Asthma         -0.7952      0.580     -1.370      0.171      -1.933       0.343
# TimelyA        -0.8221      0.379     -2.170      0.030      -1.565      -0.079
# TimelyT         0.2852      0.350      0.816      0.415      -0.400       0.970
# TimelyV         0.0040      0.323      0.013      0.990      -0.628       0.636
# Reliability    -0.3323      0.287     -1.156      0.248      -0.896       0.231
# Options         0.0157      0.303      0.052      0.959      -0.578       0.609
# HoT            -0.0885      0.312     -0.283      0.777      -0.701       0.524
# Courteous       0.3367      0.294      1.144      0.253      -0.240       0.914
# ActiveLis      -0.0509      0.277     -0.184      0.854      -0.594       0.492
# intercept      36.9912      2.311     16.007      0.000      32.461      41.521
# ==============================================================================
# Omnibus:                    41281.084   Durbin-Watson:                   0.161
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1284.210
# Skew:                           0.071   Prob(JB):                    1.37e-279
# Kurtosis:                       1.250   Cond. No.                         89.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
heatmap = df[['Initial_days', 'Age', 'ReAdmis', 'Doc_visits', 'Initial_admin', 'Asthma', 'TimelyA', 'TimelyT', 'TimelyV', 'Reliability', 'Options', 'HoT', 'Courteous', 'ActiveLis']]
sns.heatmap(heatmap.corr(), annot = False)
plt.show
heatmap.corr()
# Out:
#                Initial_days       Age   ReAdmis  Doc_visits  Initial_admin  \
# Initial_days       1.000000  0.016264  0.850862   -0.006754      -0.012058
# Age                0.016264  1.000000  0.015810    0.006898      -0.009763
# ReAdmis            0.850862  0.015810  1.000000    0.000246       0.017522
# Doc_visits        -0.006754  0.006898  0.000246    1.000000       0.012518
# Initial_admin     -0.012058 -0.009763  0.017522    0.012518       1.000000
# Asthma            -0.013496  0.009229 -0.017133   -0.017989      -0.005956
# TimelyA           -0.022258  0.005552 -0.016785    0.003680       0.006172
# TimelyT           -0.007738  0.003967 -0.002423    0.006024       0.011959
# TimelyV           -0.010817  0.004709 -0.011699   -0.002718       0.006480
# Reliability       -0.011748  0.003377 -0.001983   -0.006538      -0.002391
# Options            0.004132 -0.008827  0.005614   -0.009434       0.006063
# HoT               -0.011752 -0.002087 -0.016894    0.012530       0.016487
# Courteous          0.001279  0.009423 -0.004974    0.008589       0.008991
# ActiveLis         -0.008034 -0.003367 -0.016740    0.004571      -0.003092
#
#                  Asthma   TimelyA   TimelyT   TimelyV  Reliability   Options  \
# Initial_days  -0.013496 -0.022258 -0.007738 -0.010817    -0.011748  0.004132
# Age            0.009229  0.005552  0.003967  0.004709     0.003377 -0.008827
# ReAdmis       -0.017133 -0.016785 -0.002423 -0.011699    -0.001983  0.005614
# Doc_visits    -0.017989  0.003680  0.006024 -0.002718    -0.006538 -0.009434
# Initial_admin -0.005956  0.006172  0.011959  0.006480    -0.002391  0.006063
# Asthma         1.000000 -0.011303 -0.007648  0.000296    -0.004721  0.019796
# TimelyA       -0.011303  1.000000  0.655578  0.579585    -0.004614 -0.000368
# TimelyT       -0.007648  0.655578  1.000000  0.521728     0.003077 -0.010018
# TimelyV        0.000296  0.579585  0.521728  1.000000    -0.006324 -0.010496
# Reliability   -0.004721 -0.004614  0.003077 -0.006324     1.000000 -0.447372
# Options        0.019796 -0.000368 -0.010018 -0.010496    -0.447372  1.000000
# HoT           -0.009740  0.421233  0.366075  0.312874     0.235444 -0.310154
# Courteous     -0.013202  0.332855  0.291039  0.252302     0.192223 -0.268186
# ActiveLis      0.002209  0.278067  0.242962  0.209498     0.161528 -0.229557
#
#                     HoT  Courteous  ActiveLis
# Initial_days  -0.011752   0.001279  -0.008034
# Age           -0.002087   0.009423  -0.003367
# ReAdmis       -0.016894  -0.004974  -0.016740
# Doc_visits     0.012530   0.008589   0.004571
# Initial_admin  0.016487   0.008991  -0.003092
# Asthma        -0.009740  -0.013202   0.002209
# TimelyA        0.421233   0.332855   0.278067
# TimelyT        0.366075   0.291039   0.242962
# TimelyV        0.312874   0.252302   0.209498
# Reliability    0.235444   0.192223   0.161528
# Options       -0.310154  -0.268186  -0.229557
# HoT            1.000000   0.377368   0.319886
# Courteous      0.377368   1.000000   0.274499
# ActiveLis      0.319886   0.274499   1.000000

# %%
survey_heatmap = df[['Initial_days', 'TimelyA', 'TimelyT', 'TimelyV', 'Reliability', 'Options', 'HoT', 'Courteous', 'ActiveLis']]
sns.heatmap(survey_heatmap.corr(), annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
survey_heatmap = df[['Initial_days', 'ReAdmis', 'Initial_admin', 'TimelyA', 'Reliability']]
sns.heatmap(survey_heatmap.corr(), annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['intercept'] = 1
survey_model = sm.OLS(df['Initial_days'], df[['ReAdmis','intercept']]).fit()
print(survey_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Initial_days   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.724
# Method:                 Least Squares   F-statistic:                 2.622e+04
# Date:                Sun, 06 Nov 2022   Prob (F-statistic):               0.00
# Time:                        22:12:51   Log-Likelihood:                -40452.
# No. Observations:               10000   AIC:                         8.091e+04
# Df Residuals:                    9998   BIC:                         8.092e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ReAdmis       46.4448      0.287    161.932      0.000      45.883      47.007
# intercept     17.4147      0.174    100.239      0.000      17.074      17.755
# ==============================================================================
# Omnibus:                     1995.070   Durbin-Watson:                   1.268
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3419.325
# Skew:                           1.338   Prob(JB):                         0.00
# Kurtosis:                       4.022   Cond. No.                         2.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
res_df = pd.read_csv('E:/HDD Documents/HDD Documents/School/WGU/d208_predictive_modeling/medical_cleaned208_v4.csv')

# %%
res_df['intercept'] = 1
residuals = res_df['Initial_days'] - survey_model.predict(res_df[['Initial_admin','Asthma', 'TimelyT', 'TimelyA','intercept']])
sns.scatterplot(x=res_df['TimelyT'],y=residuals,color='red')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [32], line 2
#       1 res_df['intercept'] = 1
# ----> 2 residuals = res_df['Initial_days'] - survey_model.predict(res_df[['Asthma', 'TimelyT', 'TimelyA','intercept']])
#       3 sns.scatterplot(x=res_df['TimelyT'],y=residuals,color='red')
#
# File c:\Users\nsgoo\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:1159, in Results.predict(self, exog, transform, *args, **kwargs)
#    1156         exog = exog[:, None]
#    1157     exog = np.atleast_2d(exog)  # needed in count model shape[1]
# -> 1159 predict_results = self.model.predict(self.params, exog, *args,
#    1160                                      **kwargs)
#    1162 if exog_index is not None and not hasattr(predict_results,
#    1163                                           'predicted_values'):
#    1164     if predict_results.ndim == 1:
#
# File c:\Users\nsgoo\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:397, in RegressionModel.predict(self, params, exog)
#     394 if exog is None:
#     395     exog = self.exog
# --> 397 return np.dot(exog, params)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# ValueError: shapes (10000,4) and (5,) not aligned: 4 (dim 1) != 5 (dim 0)

# %%
res_df['intercept'] = 1
res = res_df['Initial_days'] - survey_model.predict(res_df[['Initial_admin','Asthma', 'TimelyT', 'TimelyA','intercept']])
sns.scatterplot(x = res_df['TimelyT'], y = res, color = 'red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [29], line 2
#       1 res_df['intercept'] = 1
# ----> 2 res = res_df['Initial_days'] - survey_model.predict(res_df[['Initial_admin','Asthma', 'TimelyT', 'TimelyA','intercept']])
#       3 sns.scatterplot(x = res_df['TimelyT'], y = res, color = 'red')
#       4 plt.show()
#
# File c:\Users\nsgoo\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:1159, in Results.predict(self, exog, transform, *args, **kwargs)
#    1156         exog = exog[:, None]
#    1157     exog = np.atleast_2d(exog)  # needed in count model shape[1]
# -> 1159 predict_results = self.model.predict(self.params, exog, *args,
#    1160                                      **kwargs)
#    1162 if exog_index is not None and not hasattr(predict_results,
#    1163                                           'predicted_values'):
#    1164     if predict_results.ndim == 1:
#
# File c:\Users\nsgoo\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:397, in RegressionModel.predict(self, params, exog)
#     394 if exog is None:
#     395     exog = self.exog
# --> 397 return np.dot(exog, params)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# TypeError: can't multiply sequence by non-int of type 'float'
